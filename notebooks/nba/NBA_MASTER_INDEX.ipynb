# %% [markdown]
# ---
#
# ## 01. Data Ingestion
#
# **Purpose:** Fetch, clean, and prepare NBA data from multiple sources including OddsAPI, NBA Stats API, and injury reports.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_data_ingestion.ipynb](01_data_ingestion/nba_data_ingestion.ipynb) | Fetch game logs, team stats, and odds from APIs | ✅ Active |
# | [nba_data_cleaning.ipynb](01_data_ingestion/nba_data_cleaning.ipynb) | Normalize team/player data, format odds, handle missing values | 📝 Planned |
# | [nba_feature_engineering.ipynb](01_data_ingestion/nba_feature_engineering.ipynb) | Generate PER, TS%, usage rate, advanced metrics | 📝 Planned |
# | [nba_injury_updates.ipynb](01_data_ingestion/nba_injury_updates.ipynb) | Scrape daily injury data from ESPN/NBA.com | 📝 Planned |
# | [nba_schedule_sync.ipynb](01_data_ingestion/nba_schedule_sync.ipynb) | Merge daily schedule with odds feed | 📝 Planned |

# %% [markdown]
# ---
#
# ## 02. Exploratory Data Analysis (EDA)
#
# **Purpose:** Uncover trends, patterns, and insights in NBA data through statistical analysis and visualization.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_team_trends.ipynb](02_eda/nba_team_trends.ipynb) | Analyze team performance trends, home/away splits | 📝 Planned |
# | [nba_player_trends.ipynb](02_eda/nba_player_trends.ipynb) | Track player stats, usage, efficiency over time | 📝 Planned |
# | [nba_matchup_analytics.ipynb](02_eda/nba_matchup_analytics.ipynb) | Head-to-head analysis, pace, defensive ratings | 📝 Planned |
# | [nba_odds_vs_actuals.ipynb](02_eda/nba_odds_vs_actuals.ipynb) | Compare betting lines to actual game outcomes | 📝 Planned |
# | [nba_referee_impact.ipynb](02_eda/nba_referee_impact.ipynb) | Analyze referee tendencies on fouls, pace, totals | 📝 Planned |

# %% [markdown]
# ---
#
# ## 03. Machine Learning Models
#
# **Purpose:** Build, train, and validate predictive models for spread, totals, moneyline, and player props.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_spread_model.ipynb](03_models/nba_spread_model.ipynb) | Predict point spread winners using gradient boosting | 📝 Planned |
# | [nba_total_model.ipynb](03_models/nba_total_model.ipynb) | Over/Under predictions with regression models | 📝 Planned |
# | [nba_moneyline_model.ipynb](03_models/nba_moneyline_model.ipynb) | Win probability estimation with logistic regression | 📝 Planned |
# | [nba_player_prop_model.ipynb](03_models/nba_player_prop_model.ipynb) | Points/rebounds/assists prop predictions | 📝 Planned |
# | [nba_simulation_engine.ipynb](03_models/nba_simulation_engine.ipynb) | Monte Carlo game simulations | 📝 Planned |
# | [nba_backtest.ipynb](03_models/nba_backtest.ipynb) | Historical model validation and ROI analysis | 📝 Planned |

# %% [markdown]
# ---
#
# ## 04. Betting Strategies
#
# **Purpose:** Identify value bets, build parlays, simulate bankroll management, and execute live betting strategies.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_value_bets.ipynb](04_betting/nba_value_bets.ipynb) | Edge detection using model predictions vs market odds | 📝 Planned |
# | [nba_parlay_builder.ipynb](04_betting/nba_parlay_builder.ipynb) | Correlated SGP builder with expected value calculations | 📝 Planned |
# | [nba_bankroll_simulation.ipynb](04_betting/nba_bankroll_simulation.ipynb) | Kelly Criterion, unit sizing, variance simulation | 📝 Planned |
# | [nba_live_betting.ipynb](04_betting/nba_live_betting.ipynb) | In-game betting opportunities based on live data | 📝 Planned |
# | [nba_alert_system.ipynb](04_betting/nba_alert_system.ipynb) | Telegram/Discord alerts for high-EV bets | 📝 Planned |

# %% [markdown]
# ---
#
# ## 05. Dashboards & Visualization
#
# **Purpose:** Interactive dashboards for team performance, player analytics, betting insights, and trend tracking.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_team_dashboard.ipynb](05_dashboards/nba_team_dashboard.ipynb) | Team stats, recent form, upcoming schedule | 📝 Planned |
# | [nba_player_dashboard.ipynb](05_dashboards/nba_player_dashboard.ipynb) | Player performance metrics, prop trends | 📝 Planned |
# | [nba_betting_dashboard.ipynb](05_dashboards/nba_betting_dashboard.ipynb) | Daily EV picks, bankroll tracker, ROI charts | 📝 Planned |
# | [nba_heatmaps.ipynb](05_dashboards/nba_heatmaps.ipynb) | Shot charts, defensive zones, pace heatmaps | 📝 Planned |
# | [nba_trend_tracker.ipynb](05_dashboards/nba_trend_tracker.ipynb) | Rolling stats, streaks, season-long trends | 📝 Planned |

# %% [markdown]
# ---
#
# ## 06. Automation
#
# **Purpose:** Scheduled tasks for daily data sync, odds updates, result tracking, and Git version control.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_daily_runner.ipynb](06_automation/nba_daily_runner.ipynb) | Master script to run all daily pipelines | 📝 Planned |
# | [nba_odds_sync.ipynb](06_automation/nba_odds_sync.ipynb) | Fetch and cache latest odds every 30 minutes | 📝 Planned |
# | [nba_results_update.ipynb](06_automation/nba_results_update.ipynb) | Update database with completed game results | 📝 Planned |
# | [nba_telegram_integration.ipynb](06_automation/nba_telegram_integration.ipynb) | Send daily picks and alerts to Telegram | 📝 Planned |
# | [nba_git_sync.ipynb](06_automation/nba_git_sync.ipynb) | Auto-commit notebook outputs and data snapshots | 📝 Planned |

# %% [markdown]
# ---
#
# ## 07. Experimental
#
# **Purpose:** Cutting-edge research including quantum models, clustering, market efficiency studies, and AI agent training.
#
# | Notebook | Description | Status |
# |----------|-------------|--------|
# | [nba_quantum_model.ipynb](07_experimental/nba_quantum_model.ipynb) | Quantum annealing for portfolio optimization | 📝 Planned |
# | [nba_cluster_analysis.ipynb](07_experimental/nba_cluster_analysis.ipynb) | K-means clustering for team/player archetypes | 📝 Planned |
# | [nba_market_efficiency.ipynb](07_experimental/nba_market_efficiency.ipynb) | Weak-form EMH testing on NBA betting markets | 📝 Planned |
# | [nba_agent_training.ipynb](07_experimental/nba_agent_training.ipynb) | Reinforcement learning agent for live betting | 📝 Planned |

# %% [markdown]
# ---
#
# ## Quick Launch Commands
#
# Run these cells to start your JupyterLab environment and verify dependencies.

# %%
# Environment Setup
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os, sys, pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt
from dotenv import load_dotenv
load_dotenv("C:/EQ12/.env")

sys.path.append("C:/EQ12/scripts")
from nba_utils import *

print("✅ Environment loaded successfully")
print(f"   Python: {sys.version.split()[0]}")
print(f"   Pandas: {pd.__version__}")
print(f"   NumPy: {np.__version__}")

# %%
# Verify API Keys
config = load_env_config()

print("🔑 API Key Status:")
print(f"   ODDS_API_KEY: {'✅ Set' if config['odds_api_key'] and config['odds_api_key'] != 'REPLACE_ME' else '❌ Not Set'}")
print(f"   TELEGRAM_BOT_TOKEN: {'✅ Set' if config['telegram_bot_token'] else '❌ Not Set'}")
print(f"   TELEGRAM_CHAT_ID: {'✅ Set' if config['telegram_chat_id'] else '❌ Not Set'}")
print(f"   DISCORD_WEBHOOK_URL: {'✅ Set' if config['discord_webhook_url'] else '❌ Not Set'}")
print(f"   OPENAI_API_KEY: {'✅ Set' if config['openai_api_key'] else '❌ Not Set'}")

# %%
# Test NBA Data Fetch
try:
    teams_df = fetch_nba_teams()
    print(f"✅ NBA API Available: {len(teams_df)} teams loaded")
    print("\nSample Teams:")
    print(teams_df[['abbreviation', 'city', 'full_name']].head(5))
except Exception as e:
    print(f"❌ NBA API Error: {e}")
    print("   Install with: pip install nba-api")

# %%
# List All NBA Notebooks
import os
from pathlib import Path

nba_dir = Path("C:/EQ12_BROKEN_20251122_210342/notebooks/nba")
categories = ['01_data_ingestion', '02_eda', '03_models', '04_betting', '05_dashboards', '06_automation', '07_experimental']

print("📊 NBA Notebooks Inventory:\n")
total_notebooks = 0

for category in categories:
    cat_path = nba_dir / category
    if cat_path.exists():
        notebooks = list(cat_path.glob("*.ipynb"))
        print(f"{category.replace('_', ' ').title()}: {len(notebooks)} notebooks")
        total_notebooks += len(notebooks)
        for nb in notebooks:
            print(f"   - {nb.name}")
    else:
        print(f"{category.replace('_', ' ').title()}: Directory not found")

print(f"\n📈 Total Notebooks: {total_notebooks}")

# %% [markdown]
# ---
#
# ## Next Steps
#
# 1. **Start Docker Container:**
#    ```bash
#    docker start eq12-jupyter-dataviz
#    docker exec eq12-jupyter-dataviz jupyter server list
#    ```
#
# 2. **Access JupyterLab:**
#    - URL: http://localhost:8889/?token=eq12-dataviz-token
#
# 3. **Create Missing Notebooks:**
#    - Use this index to track which notebooks are completed vs planned
#    - Follow the standard template in `nba_utils.py` for consistency
#
# 4. **Set Up Automation:**
#    - Configure `nba_daily_runner.ipynb` to execute all pipelines
#    - Schedule via Windows Task Scheduler or cron
#
# 5. **Monitor Performance:**
#    - Track betting ROI in `nba_betting_dashboard.ipynb`
#    - Log all picks to `C:/EQ12/logs/nba_picks_YYYYMMDD.json`
#
# ---
#
# **Last Updated:** 2025-11-27
# **Maintainer:** EQ12 Expert Quantum System
